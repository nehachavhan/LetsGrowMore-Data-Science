# %% [markdown]
# # Author:Neha Sanjay Chavhan
#
#
# # Task 3- Image to Pencil Sketch with Python

# %%
pip install opencv-contrib-python-headless
# Out:
# Requirement already satisfied: opencv-contrib-python-headless in c:\users\asus\anaconda3\lib\site-packages (4.5.4.58)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\asus\anaconda3\lib\site-packages (from opencv-contrib-python-headless) (1.20.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing the Libraries

import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Load the Image

image=cv2.imread("download.jpg")

# %%
# Read the image in RGB format

im_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,6))
plt.imshow(im_rgb)
plt.title("Original Image")
plt.axis("off");

# %%
plt.imshow(image)

# %%
# Convert the original image to grayscale image

gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(10,6))
plt.imshow(gray_image,cmap="gray")
plt.title("GrayScale Image")
plt.axis("off");

# %%
# Inverting image 

inverted_image=255-gray_image
plt.figure(figsize=(10,6))
plt.imshow(inverted_image,cmap="gray")
plt.title("Inverted Image")
plt.axis("off");

# %%
# Blur image

blur=cv2.GaussianBlur(inverted_image,(21,21),0)
plt.figure(figsize=(10,6))
plt.imshow(blur,cmap="gray")
plt.title("Smoothen Image")
plt.axis("off");

# %%
# Convert image to Pencil Sketch

sketch=cv2.divide(gray_image,255-blur,scale=255)
plt.figure(figsize=(10,6))
plt.imshow(sketch,cmap="gray")
plt.title("Final Sketch Image")
plt.axis("off");
